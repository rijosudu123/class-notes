# %% [markdown]
# <a href="https://colab.research.google.com/github/rijosudu123/class-notes/blob/main/ict_assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bank Account Manager

# %%
class bank_account:
  def __init__(self,accno,cust_name,balance):
    self.accno = accno
    self.cust_name = cust_name
    self.balance = balance

  def deposit(self, amount):
    if amount>0:
      self.balance+=amount
      print(f"Amount: {amount:.2f} is added to your account. Your A/C balance is {self.balance:.2f}")
    else:
      print("please enter an amount greater than zero")

  def withdraw(self, amount):
    if amount>0:
      if amount>self.balance:
        print("Insufficient balance")
      else:
        self.balance-= amount
        print(f"Amount {amount:.2f} debited from your A/C. Your current balance is {self.balance:.2f}")
    else:
      print("please enter an amount greater than zero")

  def check_balance(self):
    print(f"A/C No: {self.accno} of {self.cust_name} has balance of {self.balance}")

cust1=bank_account(94974417, "Rijoy S",100000)
cust1.check_balance()
cust1.withdraw(5000)
cust1.deposit(5500)
# Out:
# A/C No: 94974417 of Rijoy S has balance of 100000
# Amount 5000.00 debited from your A/C. Your current balance is 95000.00
# Amount: 5500.00 is added to your account. Your A/C balance is 100500.00

# %% [markdown]
# # Weather Data Analyzer

# %%
temperature = [25,30,24,20,40]
humidity = [85,80,90,45,68]
wind = [24,20,16,28,35]

avg_temp = sum(temperature)/len(temperature)
avg_humid = sum(humidity)/len(humidity)
avg_wind = sum(wind)/len(wind)

print("Average temperature ",avg_temp)
print("Average humidity ", avg_humid)
print("Average wind ", avg_wind)

if avg_temp>30 and avg_humid<60:
  print("It's Sunny Day")
elif avg_humid>85:
  print("It's Rainy Day")
elif avg_wind>35:
  print("It's Windy Day")
else:
  print("It's Moderate / Cloudy Day")
# Out:
# Average temperature  27.8
# Average humidity  73.6
# Average wind  24.6
# It's Moderate / Cloudy Day
